# %% [markdown]
# Università degli Studi di Palermo
#
# Corso di Laurea Magistrale in **Ingegneria Informatica**
#
# **Assignment 1** di **Visione Artificiale** - **Strumento per la navigazione di immagini a 360°**
#
# Sviluppato da **Castelli Giovanni**, **Costa Gabriele Nicolò**, **Sollazzo Ivan**.

# %%
# Importazione delle librerie necessarie
import numpy as np
import cv2

# %% [markdown]
# # Funzioni immagini

# %% [markdown]
# ### Funzione per la riproduzione di un video

# %%
def open_video(path):

    # Importazione del video
    video = cv2.VideoCapture(path)

    # Riproduci il video fintantoché aperto
    while video.isOpened():

        # Leggi frame per frame
        ret, frame = video.read()

        # Verifica se c'è il frame
        if ret:
            # Visualizza il frame
            cv2.imshow("Frame", frame)
        else:
            print("Errore nella lettura del frame.")

        # Verifica se il tasto premuto è q
        if cv2.waitKey(25) == ord('q'):
            print("Uscita in corso dal video...")

            # Rilascia il video e distruggi tutte le finestre
            video.release()
            cv2.destroyAllWindows()

# %% [markdown]
# ### Funzione per la cattura di un frame

# %%
def capture_frame(path, frameNumber = 1):
    # Importazione del video
    video = cv2.VideoCapture(path)

    # Contatore frame
    frameCount = frameNumber

    # Verifica se il video è aperto correttamente
    if video.isOpened():
        while video.isOpened():

            # Posizionati sul frame frameCount - 1
            video.set(cv2.CAP_PROP_POS_FRAMES, frameCount - 1)

            # Leggi il frame
            ret, frame = video.read()

            if ret:
                video.release()
                return frame
            else:
                print("Errore durante la lettura del frame.")
                frameCount += 1

    else:
        print("Errore durante l'apertura del video.")

# %% [markdown]
# ### Funzione per l'inverse mapping

# %%
def inverse_map(input_image, w_output, h_output, latitude, longitude, fov):

    # Calcolo dimensioni immagine equirettangolare
    h_input, w_input = input_image.shape[0], input_image.shape[1]

    # Conversione da gradi a radianti
    latitude_rad = np.radians(latitude)
    longitude_rad = np.radians(longitude)
    fov_rad = np.radians(fov)

    # Creazione di un piano tangente scalato
    u = np.linspace(-1, 1, w_output) * np.tan(fov_rad / 2)
    v = np.linspace(-1, 1, h_output) * np.tan(fov_rad / 2)
    U, V = np.meshgrid(u, v)

    # Costruzione dei vettori nel piano tangente, assumendo x = 1
    X = np.ones_like(U) * zoom
    Y = U.copy()
    Z = -V.copy()

    # Definizione delle matrici di rotazione
    Ry = np.array([[np.cos(latitude_rad), 0, np.sin(latitude_rad)], [0, 1, 0], [-np.sin(latitude_rad), 0, np.cos(latitude_rad)]])
    Rz = np.array([[np.cos(longitude_rad), -np.sin(longitude_rad), 0], [np.sin(longitude_rad), np.cos(longitude_rad), 0], [0, 0, 1]])

    # Costruzione dei vettori intersecanti il piano
    V_initial = np.stack((X, Y, Z), axis=-1)

    # Rotazione del piano
    V_rotated = V_initial @ Ry @ Rz

    # Normalizzazione
    V_normalized = V_rotated / np.linalg.norm(V_rotated, axis=-1, keepdims=True)

    # Calcolo delle coordinate sferiche
    theta = np.arccos(V_normalized[..., 2])
    phi = np.arctan2(V_normalized[..., 1 ], V_normalized[...,0])

    # Mappatura alle coordinate dell'immagine equirettangolare
    map_x = (((phi / np.pi) + 1) * (w_input / 2)).astype(np.float32)
    map_y  = ((theta / (np.pi)) * h_input).astype(np.float32)

    # Creazione di un'immagine planare
    output_image = np.zeros((h_output, w_output, 3), dtype=np.uint8)

    # Utilizzo di remap per effettuare l'interpolazione
    output_image = cv2.remap(input_image, map_x, map_y, interpolation=cv2.INTER_LINEAR)

    return output_image

# %% [markdown]
# ### Funzione per gestire l'input da tastiera

# %%
# Parametri da gestire
lat = 0
long = 0
FOV = 60
zoom = 1
w = 500 #lunghezza dell'immagine
h = 500 #altezza dell'immagine

# Funzione per la gestione dell'input da tastiera
def tastiera():
    global lat, long, FOV, zoom, w, h, paused
    # Aspetta l'input da tastiera
    key = cv2.waitKey(1) & 0xFF
    #print(key) utile per capire il codice del tasto che clicco
    # Se la freccia su è premuta
    if key == ord('w'):  
        lat += 1
    # Se la freccia giù è premuta
    elif key == ord('s'):  
        lat -= 1
    # Se la freccia destra è premuta
    elif key == ord('a'):  
        long += 1
    # Se la freccia sinistra è premuta
    elif key == ord('d'): 
        long -= 1
    # Se il tasto c è premuto zooma
    elif key == ord('c'):  
        zoom +=0.1
        if zoom > 10:
            zoom = 10  
    # Se il tasto v è premuto dezooma
    elif key == ord('v'): 
        zoom -= 0.1
        if zoom < 1:
            zoom = 1
    # Se il tasto x è premuto aumenta il FOV
    elif key == ord('x'):
        FOV += 1
    # Se il tasto z è premuto diminuisci il FOV
    elif key == ord('z'):
        FOV -= 1
    # Se il tasto 'q' è premuto, esce dal ciclo
    elif key == ord('q'):
        return False
    elif key == ord('t'):
        if not paused:
            paused = True
        else:
            paused = False
    return True

# %% [markdown]
# ### Funzione per mostrare i frame

# %%
# Funzione per mostrare i frame
def show_frame(frame, title="Frame"):
    # Mostra il frame
    cv2.imshow(title, frame)
    if not tastiera(): #se tastiera restituisce False (ovvero premo q)
        cv2.destroyAllWindows() #distruggo l'immagine
        return False
    return True

# %% [markdown]
# ### Funzione per mostrare l'immagine planare

# %%
def show_planar(frame):
    bool = True
    while bool:
        plane_image = inverse_map(frame, w, h, lat, long, FOV) #genero la nuova immagine
        if not show_frame(plane_image):
            bool = False

# %% [markdown]
# # Demo immagine

# %%
# Cattura del frame
frame = capture_frame("video_1.MP4")

# Mostra il frame
show_planar(frame)

# %% [markdown]
# # Funzioni video

# %% [markdown]
# ### Funzione per la cattura dei frame di un video in un array

# %%
def capture_video_frames(path):
    video = cv2.VideoCapture(path)
    nFrames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    frames = []

    for i in range(1, nFrames):
        frame = capture_frame(path, i)
        print(f"Saving frame {i} of {int(nFrames)}...")
        frames.append(frame)
    
    return frames

# %% [markdown]
# ### Funzione per la riproduzione del video

# %%
def play_video(video_array):

    # Metodo di processamento del frame
    def process_frame(frame):
        plane_image = inverse_map(frame, w, h, lat, long, FOV)
        return plane_image
    
    # Loop di esecuzione
    i = 0
    running = True

    while running:
        if i < len(video_array):
            frame = video_array[i]
            plane_image_final = process_frame(frame)

            if not show_frame(plane_image_final):
                break
            if paused:
                while True:
                    plane_image_final = process_frame(video_array[i])
                    if not show_frame(plane_image_final):
                        running = False
                        break
                    if not paused:
                        break
                if not running:
                    break
            i += 1
        else:
            cv2.destroyAllWindows()
            running = False

# %% [markdown]
# # Demo video

# %%
paused = False
video_array = capture_video_frames("video_1.MP4")
play_video(video_array)
# Out:
# Saving frame 1 of 1140...
# Saving frame 2 of 1140...
# Saving frame 3 of 1140...
# Saving frame 4 of 1140...
# Saving frame 5 of 1140...
# Saving frame 6 of 1140...
# Saving frame 7 of 1140...
# Saving frame 8 of 1140...
# Saving frame 9 of 1140...
# Saving frame 10 of 1140...
# Saving frame 11 of 1140...
# Saving frame 12 of 1140...
# Saving frame 13 of 1140...
# Saving frame 14 of 1140...
# Saving frame 15 of 1140...
# Saving frame 16 of 1140...
# Saving frame 17 of 1140...
# Saving frame 18 of 1140...
# Saving frame 19 of 1140...
# Saving frame 20 of 1140...
# Saving frame 21 of 1140...
# Saving frame 22 of 1140...
# Saving frame 23 of 1140...
# Saving frame 24 of 1140...
# Saving frame 25 of 1140...
# Saving frame 26 of 1140...
# Saving frame 27 of 1140...
# Saving frame 28 of 1140...
# Saving frame 29 of 1140...
# Saving frame 30 of 1140...
# Saving frame 31 of 1140...
# Saving frame 32 of 1140...
# Saving frame 33 of 1140...
# Saving frame 34 of 1140...
# Saving frame 35 of 1140...
# Saving frame 36 of 1140...
# Saving frame 37 of 1140...
# Saving frame 38 of 1140...
# Saving frame 39 of 1140...
# Saving frame 40 of 1140...
# Saving frame 41 of 1140...
# Saving frame 42 of 1140...
# Saving frame 43 of 1140...
# Saving frame 44 of 1140...
# Saving frame 45 of 1140...
# Saving frame 46 of 1140...
# Saving frame 47 of 1140...
# Saving frame 48 of 1140...
# Saving frame 49 of 1140...
# Saving frame 50 of 1140...
# Saving frame 51 of 1140...
# Saving frame 52 of 1140...
# Saving frame 53 of 1140...
# Saving frame 54 of 1140...
# Saving frame 55 of 1140...
# Saving frame 56 of 1140...
# Saving frame 57 of 1140...
# Saving frame 58 of 1140...
# Saving frame 59 of 1140...
# Saving frame 60 of 1140...
# Saving frame 61 of 1140...
# Saving frame 62 of 1140...
# Saving frame 63 of 1140...
# Saving frame 64 of 1140...
# Saving frame 65 of 1140...
# Saving frame 66 of 1140...
# Saving frame 67 of 1140...
# Saving frame 68 of 1140...
# Saving frame 69 of 1140...
# Saving frame 70 of 1140...
# Saving frame 71 of 1140...
# Saving frame 72 of 1140...
# Saving frame 73 of 1140...
# Saving frame 74 of 1140...
# Saving frame 75 of 1140...
# Saving frame 76 of 1140...
# Saving frame 77 of 1140...
# Saving frame 78 of 1140...
# Saving frame 79 of 1140...
# Saving frame 80 of 1140...
# Saving frame 81 of 1140...
# Saving frame 82 of 1140...
# Saving frame 83 of 1140...
# Saving frame 84 of 1140...
# Saving frame 85 of 1140...
# Saving frame 86 of 1140...
# Saving frame 87 of 1140...
# Saving frame 88 of 1140...
# Saving frame 89 of 1140...
# Saving frame 90 of 1140...
# Saving frame 91 of 1140...
# Saving frame 92 of 1140...
# Saving frame 93 of 1140...
# Saving frame 94 of 1140...
# Saving frame 95 of 1140...
# Saving frame 96 of 1140...
# Saving frame 97 of 1140...
# Saving frame 98 of 1140...
# Saving frame 99 of 1140...
# Saving frame 100 of 1140...
# Saving frame 101 of 1140...
# Saving frame 102 of 1140...
# Saving frame 103 of 1140...
# Saving frame 104 of 1140...
# Saving frame 105 of 1140...
# Saving frame 106 of 1140...
# Saving frame 107 of 1140...
# Saving frame 108 of 1140...
# Saving frame 109 of 1140...
# Saving frame 110 of 1140...
# Saving frame 111 of 1140...
# Saving frame 112 of 1140...
# Saving frame 113 of 1140...
# Saving frame 114 of 1140...
# Saving frame 115 of 1140...
# Saving frame 116 of 1140...
# Saving frame 117 of 1140...
# Saving frame 118 of 1140...
# Saving frame 119 of 1140...
# Saving frame 120 of 1140...
# Saving frame 121 of 1140...
# Saving frame 122 of 1140...
# Saving frame 123 of 1140...
# Saving frame 124 of 1140...
# Saving frame 125 of 1140...
# Saving frame 126 of 1140...
# Saving frame 127 of 1140...
# Saving frame 128 of 1140...
# Saving frame 129 of 1140...
# Saving frame 130 of 1140...
# Saving frame 131 of 1140...
# Saving frame 132 of 1140...
# Saving frame 133 of 1140...
# Saving frame 134 of 1140...
# Saving frame 135 of 1140...
# Saving frame 136 of 1140...
# Saving frame 137 of 1140...
# Saving frame 138 of 1140...
# Saving frame 139 of 1140...
# Saving frame 140 of 1140...
# Saving frame 141 of 1140...
# Saving frame 142 of 1140...
# Saving frame 143 of 1140...
# Saving frame 144 of 1140...
# Saving frame 145 of 1140...
# Saving frame 146 of 1140...
# Saving frame 147 of 1140...
# Saving frame 148 of 1140...
# Saving frame 149 of 1140...
# Saving frame 150 of 1140...
# Saving frame 151 of 1140...
# Saving frame 152 of 1140...
# Saving frame 153 of 1140...
# Saving frame 154 of 1140...
# Saving frame 155 of 1140...
# Saving frame 156 of 1140...
# Saving frame 157 of 1140...
# Saving frame 158 of 1140...
# Saving frame 159 of 1140...
# Saving frame 160 of 1140...
# Saving frame 161 of 1140...
# Saving frame 162 of 1140...
# Saving frame 163 of 1140...
# Saving frame 164 of 1140...
# Saving frame 165 of 1140...
# Saving frame 166 of 1140...
# Saving frame 167 of 1140...
# Saving frame 168 of 1140...
# Saving frame 169 of 1140...
# Saving frame 170 of 1140...
# Saving frame 171 of 1140...
# Saving frame 172 of 1140...
# Saving frame 173 of 1140...
# Saving frame 174 of 1140...
# Saving frame 175 of 1140...
# Saving frame 176 of 1140...
# Saving frame 177 of 1140...
# Saving frame 178 of 1140...
# Saving frame 179 of 1140...
# Saving frame 180 of 1140...
# Saving frame 181 of 1140...
# Saving frame 182 of 1140...
# Saving frame 183 of 1140...
# Saving frame 184 of 1140...
# Saving frame 185 of 1140...
# Saving frame 186 of 1140...
# Saving frame 187 of 1140...
# Saving frame 188 of 1140...
# Saving frame 189 of 1140...
# Saving frame 190 of 1140...
# Saving frame 191 of 1140...
# Saving frame 192 of 1140...
# Saving frame 193 of 1140...
# Saving frame 194 of 1140...
# Saving frame 195 of 1140...
# Saving frame 196 of 1140...
# Saving frame 197 of 1140...
# Saving frame 198 of 1140...
# Saving frame 199 of 1140...
# Saving frame 200 of 1140...
# Saving frame 201 of 1140...
# Saving frame 202 of 1140...
# Saving frame 203 of 1140...
# Saving frame 204 of 1140...
# Saving frame 205 of 1140...
# Saving frame 206 of 1140...
# Saving frame 207 of 1140...
# Saving frame 208 of 1140...
# Saving frame 209 of 1140...
# Saving frame 210 of 1140...
# Saving frame 211 of 1140...
# Saving frame 212 of 1140...
# Saving frame 213 of 1140...
# Saving frame 214 of 1140...
# Saving frame 215 of 1140...
# Saving frame 216 of 1140...
# Saving frame 217 of 1140...
# Saving frame 218 of 1140...
# Saving frame 219 of 1140...
# Saving frame 220 of 1140...
# Saving frame 221 of 1140...
# Saving frame 222 of 1140...
# Saving frame 223 of 1140...
# Saving frame 224 of 1140...
# Saving frame 225 of 1140...
# Saving frame 226 of 1140...
# Saving frame 227 of 1140...
# Saving frame 228 of 1140...
# Saving frame 229 of 1140...
# Saving frame 230 of 1140...
# Saving frame 231 of 1140...
# Saving frame 232 of 1140...
# Saving frame 233 of 1140...
# Saving frame 234 of 1140...
# Saving frame 235 of 1140...
# Saving frame 236 of 1140...
# Saving frame 237 of 1140...
# Saving frame 238 of 1140...
# Saving frame 239 of 1140...
# Saving frame 240 of 1140...
# Saving frame 241 of 1140...
# Saving frame 242 of 1140...
# Saving frame 243 of 1140...
# Saving frame 244 of 1140...
# Saving frame 245 of 1140...
# Saving frame 246 of 1140...
# Saving frame 247 of 1140...
# Saving frame 248 of 1140...
# Saving frame 249 of 1140...
# Saving frame 250 of 1140...
# Saving frame 251 of 1140...
# Saving frame 252 of 1140...
# Saving frame 253 of 1140...
# Saving frame 254 of 1140...
# Saving frame 255 of 1140...
# Saving frame 256 of 1140...
# Saving frame 257 of 1140...
# Saving frame 258 of 1140...
# Saving frame 259 of 1140...
# Saving frame 260 of 1140...
# Saving frame 261 of 1140...
# Saving frame 262 of 1140...
# Saving frame 263 of 1140...
# Saving frame 264 of 1140...
# Saving frame 265 of 1140...
# Saving frame 266 of 1140...
# Saving frame 267 of 1140...
# Saving frame 268 of 1140...
# Saving frame 269 of 1140...
# Saving frame 270 of 1140...
# Saving frame 271 of 1140...
# Saving frame 272 of 1140...
# Saving frame 273 of 1140...
# Saving frame 274 of 1140...
# Saving frame 275 of 1140...
# Saving frame 276 of 1140...
# Saving frame 277 of 1140...
# Saving frame 278 of 1140...
# Saving frame 279 of 1140...
# Saving frame 280 of 1140...
# Saving frame 281 of 1140...
# Saving frame 282 of 1140...
# Saving frame 283 of 1140...
# Saving frame 284 of 1140...
# Saving frame 285 of 1140...
# Saving frame 286 of 1140...
# Saving frame 287 of 1140...
# Saving frame 288 of 1140...
# Saving frame 289 of 1140...
# Saving frame 290 of 1140...
# Saving frame 291 of 1140...
# Saving frame 292 of 1140...
# Saving frame 293 of 1140...
# Saving frame 294 of 1140...
# Saving frame 295 of 1140...
# Saving frame 296 of 1140...
# Saving frame 297 of 1140...
# Saving frame 298 of 1140...
# Saving frame 299 of 1140...
# Saving frame 300 of 1140...
# Saving frame 301 of 1140...
# Saving frame 302 of 1140...
# Saving frame 303 of 1140...
# Saving frame 304 of 1140...
# Saving frame 305 of 1140...
# Saving frame 306 of 1140...
# Saving frame 307 of 1140...
# Saving frame 308 of 1140...
# Saving frame 309 of 1140...
# Saving frame 310 of 1140...
# Saving frame 311 of 1140...
# Saving frame 312 of 1140...
# Saving frame 313 of 1140...
# Saving frame 314 of 1140...
# Saving frame 315 of 1140...
# Saving frame 316 of 1140...
# Saving frame 317 of 1140...
# Saving frame 318 of 1140...
# Saving frame 319 of 1140...
# Saving frame 320 of 1140...
# Saving frame 321 of 1140...
# Saving frame 322 of 1140...
# Saving frame 323 of 1140...
# Saving frame 324 of 1140...
# Saving frame 325 of 1140...
# Saving frame 326 of 1140...
# Saving frame 327 of 1140...
# Saving frame 328 of 1140...
# Saving frame 329 of 1140...
# Saving frame 330 of 1140...
# Saving frame 331 of 1140...
# Saving frame 332 of 1140...
# Saving frame 333 of 1140...
# Saving frame 334 of 1140...
# Saving frame 335 of 1140...
# Saving frame 336 of 1140...
# Saving frame 337 of 1140...
# Saving frame 338 of 1140...
# Saving frame 339 of 1140...
# Saving frame 340 of 1140...
# Saving frame 341 of 1140...
# Saving frame 342 of 1140...
# Saving frame 343 of 1140...
# Saving frame 344 of 1140...
# Saving frame 345 of 1140...
# Saving frame 346 of 1140...
# Saving frame 347 of 1140...
# Saving frame 348 of 1140...
# Saving frame 349 of 1140...
# Saving frame 350 of 1140...
# Saving frame 351 of 1140...
# Saving frame 352 of 1140...
# Saving frame 353 of 1140...
# Saving frame 354 of 1140...
# Saving frame 355 of 1140...
# Saving frame 356 of 1140...
# Saving frame 357 of 1140...
# Saving frame 358 of 1140...
# Saving frame 359 of 1140...
# Saving frame 360 of 1140...
# Saving frame 361 of 1140...
# Saving frame 362 of 1140...
# Saving frame 363 of 1140...
# Saving frame 364 of 1140...
# Saving frame 365 of 1140...
# Saving frame 366 of 1140...
# Saving frame 367 of 1140...
# Saving frame 368 of 1140...
# Saving frame 369 of 1140...
# Saving frame 370 of 1140...
# Saving frame 371 of 1140...
# Saving frame 372 of 1140...
# Saving frame 373 of 1140...
# Saving frame 374 of 1140...
# Saving frame 375 of 1140...
# Saving frame 376 of 1140...
# Saving frame 377 of 1140...
# Saving frame 378 of 1140...
# Saving frame 379 of 1140...
# Saving frame 380 of 1140...
# Saving frame 381 of 1140...
# Saving frame 382 of 1140...
# Saving frame 383 of 1140...
# Saving frame 384 of 1140...
# Saving frame 385 of 1140...
# Saving frame 386 of 1140...
# Saving frame 387 of 1140...
# Saving frame 388 of 1140...
# Saving frame 389 of 1140...
# Saving frame 390 of 1140...
# Saving frame 391 of 1140...
# Saving frame 392 of 1140...
# Saving frame 393 of 1140...
# Saving frame 394 of 1140...
# Saving frame 395 of 1140...
# Saving frame 396 of 1140...
# Saving frame 397 of 1140...
# Saving frame 398 of 1140...
# Saving frame 399 of 1140...
# Saving frame 400 of 1140...
# Saving frame 401 of 1140...
# Saving frame 402 of 1140...
# Saving frame 403 of 1140...
# Saving frame 404 of 1140...
# Saving frame 405 of 1140...
# Saving frame 406 of 1140...
# Saving frame 407 of 1140...
# Saving frame 408 of 1140...
# Saving frame 409 of 1140...
# Saving frame 410 of 1140...
# Saving frame 411 of 1140...
# Saving frame 412 of 1140...
# Saving frame 413 of 1140...
# Saving frame 414 of 1140...
# Saving frame 415 of 1140...
# Saving frame 416 of 1140...
# Saving frame 417 of 1140...
# Saving frame 418 of 1140...
# Saving frame 419 of 1140...
# Saving frame 420 of 1140...
# Saving frame 421 of 1140...
# Saving frame 422 of 1140...
# Saving frame 423 of 1140...
# Saving frame 424 of 1140...
# Saving frame 425 of 1140...
# Saving frame 426 of 1140...
# Saving frame 427 of 1140...
# Saving frame 428 of 1140...
# Saving frame 429 of 1140...
# Saving frame 430 of 1140...
# Saving frame 431 of 1140...
# Saving frame 432 of 1140...
# Saving frame 433 of 1140...
# Saving frame 434 of 1140...
# Saving frame 435 of 1140...
# Saving frame 436 of 1140...
# Saving frame 437 of 1140...
# Saving frame 438 of 1140...
# Saving frame 439 of 1140...
# Saving frame 440 of 1140...
# Saving frame 441 of 1140...
# Saving frame 442 of 1140...
# Saving frame 443 of 1140...
# Saving frame 444 of 1140...
# Saving frame 445 of 1140...
# Saving frame 446 of 1140...
# Saving frame 447 of 1140...
# Saving frame 448 of 1140...
# Saving frame 449 of 1140...
# Saving frame 450 of 1140...
# Saving frame 451 of 1140...
# Saving frame 452 of 1140...
# Saving frame 453 of 1140...
# Saving frame 454 of 1140...
# Saving frame 455 of 1140...
# Saving frame 456 of 1140...
# Saving frame 457 of 1140...
# Saving frame 458 of 1140...
# Saving frame 459 of 1140...
# Saving frame 460 of 1140...
# Saving frame 461 of 1140...
# Saving frame 462 of 1140...
# Saving frame 463 of 1140...
# Saving frame 464 of 1140...
# Saving frame 465 of 1140...
# Saving frame 466 of 1140...
# Saving frame 467 of 1140...
# Saving frame 468 of 1140...
# Saving frame 469 of 1140...
# Saving frame 470 of 1140...
# Saving frame 471 of 1140...
# Saving frame 472 of 1140...
# Saving frame 473 of 1140...
# Saving frame 474 of 1140...
# Saving frame 475 of 1140...
# Saving frame 476 of 1140...
# Saving frame 477 of 1140...
# Saving frame 478 of 1140...
# Saving frame 479 of 1140...
# Saving frame 480 of 1140...
# Saving frame 481 of 1140...
# Saving frame 482 of 1140...
# Saving frame 483 of 1140...
# Saving frame 484 of 1140...
# Saving frame 485 of 1140...
# Saving frame 486 of 1140...
# Saving frame 487 of 1140...
# Saving frame 488 of 1140...
# Saving frame 489 of 1140...
# Saving frame 490 of 1140...
# Saving frame 491 of 1140...
# Saving frame 492 of 1140...
# Saving frame 493 of 1140...
# Saving frame 494 of 1140...
# Saving frame 495 of 1140...
# Saving frame 496 of 1140...
# Saving frame 497 of 1140...
# Saving frame 498 of 1140...
# Saving frame 499 of 1140...
# Saving frame 500 of 1140...
# Saving frame 501 of 1140...
# Saving frame 502 of 1140...
# Saving frame 503 of 1140...
# Saving frame 504 of 1140...
# Saving frame 505 of 1140...
# Saving frame 506 of 1140...
# Saving frame 507 of 1140...
# Saving frame 508 of 1140...
# Saving frame 509 of 1140...
# Saving frame 510 of 1140...
# Saving frame 511 of 1140...
# Saving frame 512 of 1140...
# Saving frame 513 of 1140...
# Saving frame 514 of 1140...
# Saving frame 515 of 1140...
# Saving frame 516 of 1140...
# Saving frame 517 of 1140...
# Saving frame 518 of 1140...
# Saving frame 519 of 1140...
# Saving frame 520 of 1140...
# Saving frame 521 of 1140...
# Saving frame 522 of 1140...
# Saving frame 523 of 1140...
# Saving frame 524 of 1140...
# Saving frame 525 of 1140...
# Saving frame 526 of 1140...
# Saving frame 527 of 1140...
# Saving frame 528 of 1140...
# Saving frame 529 of 1140...
# Saving frame 530 of 1140...
# Saving frame 531 of 1140...
# Saving frame 532 of 1140...
# Saving frame 533 of 1140...
# Saving frame 534 of 1140...
# Saving frame 535 of 1140...
# Saving frame 536 of 1140...
# Saving frame 537 of 1140...
# Saving frame 538 of 1140...
# Saving frame 539 of 1140...
# Saving frame 540 of 1140...
# Saving frame 541 of 1140...
# Saving frame 542 of 1140...
# Saving frame 543 of 1140...
# Saving frame 544 of 1140...
# Saving frame 545 of 1140...
# Saving frame 546 of 1140...
# Saving frame 547 of 1140...
# Saving frame 548 of 1140...
# Saving frame 549 of 1140...
# Saving frame 550 of 1140...
# Saving frame 551 of 1140...
# Saving frame 552 of 1140...
# Saving frame 553 of 1140...
# Saving frame 554 of 1140...
# Saving frame 555 of 1140...
# Saving frame 556 of 1140...
# Saving frame 557 of 1140...
# Saving frame 558 of 1140...
# Saving frame 559 of 1140...
# Saving frame 560 of 1140...
# Saving frame 561 of 1140...
# Saving frame 562 of 1140...
# Saving frame 563 of 1140...
# Saving frame 564 of 1140...
# Saving frame 565 of 1140...
# Saving frame 566 of 1140...
# Saving frame 567 of 1140...
# Saving frame 568 of 1140...
# Saving frame 569 of 1140...
# Saving frame 570 of 1140...
# Saving frame 571 of 1140...
# Saving frame 572 of 1140...
# Saving frame 573 of 1140...
# Saving frame 574 of 1140...
# Saving frame 575 of 1140...
# Saving frame 576 of 1140...
# Saving frame 577 of 1140...
# Saving frame 578 of 1140...
# Saving frame 579 of 1140...
# Saving frame 580 of 1140...
# Saving frame 581 of 1140...
# Saving frame 582 of 1140...
# Saving frame 583 of 1140...
# Saving frame 584 of 1140...
# Saving frame 585 of 1140...
# Saving frame 586 of 1140...
# Saving frame 587 of 1140...
# Saving frame 588 of 1140...
# Saving frame 589 of 1140...
# Saving frame 590 of 1140...
# Saving frame 591 of 1140...
# Saving frame 592 of 1140...
# Saving frame 593 of 1140...
# Saving frame 594 of 1140...
# Saving frame 595 of 1140...
# Saving frame 596 of 1140...
# Saving frame 597 of 1140...
# Saving frame 598 of 1140...
# Saving frame 599 of 1140...
# Saving frame 600 of 1140...
# Saving frame 601 of 1140...
# Saving frame 602 of 1140...
# Saving frame 603 of 1140...
# Saving frame 604 of 1140...
# Saving frame 605 of 1140...
# Saving frame 606 of 1140...
# Saving frame 607 of 1140...
# Saving frame 608 of 1140...
# Saving frame 609 of 1140...
# Saving frame 610 of 1140...
# Saving frame 611 of 1140...
# Saving frame 612 of 1140...
# Saving frame 613 of 1140...
# Saving frame 614 of 1140...
# Saving frame 615 of 1140...
# Saving frame 616 of 1140...
# Saving frame 617 of 1140...
# Saving frame 618 of 1140...
# Saving frame 619 of 1140...
# Saving frame 620 of 1140...
# Saving frame 621 of 1140...
# Saving frame 622 of 1140...
# Saving frame 623 of 1140...
# Saving frame 624 of 1140...
# Saving frame 625 of 1140...
# Saving frame 626 of 1140...
# Saving frame 627 of 1140...
# Saving frame 628 of 1140...
# Saving frame 629 of 1140...
# Saving frame 630 of 1140...
# Saving frame 631 of 1140...
# Saving frame 632 of 1140...
# Saving frame 633 of 1140...
# Saving frame 634 of 1140...
# Saving frame 635 of 1140...
# Saving frame 636 of 1140...
# Saving frame 637 of 1140...
# Saving frame 638 of 1140...
# Saving frame 639 of 1140...
# Saving frame 640 of 1140...
# Saving frame 641 of 1140...
# Saving frame 642 of 1140...
# Saving frame 643 of 1140...
# Saving frame 644 of 1140...
# Saving frame 645 of 1140...
# Saving frame 646 of 1140...
# Saving frame 647 of 1140...
# Saving frame 648 of 1140...
# Saving frame 649 of 1140...
# Saving frame 650 of 1140...
# Saving frame 651 of 1140...
# Saving frame 652 of 1140...
# Saving frame 653 of 1140...
# Saving frame 654 of 1140...
# Saving frame 655 of 1140...
# Saving frame 656 of 1140...
# Saving frame 657 of 1140...
# Saving frame 658 of 1140...
# Saving frame 659 of 1140...
# Saving frame 660 of 1140...
# Saving frame 661 of 1140...
# Saving frame 662 of 1140...
# Saving frame 663 of 1140...
# Saving frame 664 of 1140...
# Saving frame 665 of 1140...
# Saving frame 666 of 1140...
# Saving frame 667 of 1140...
# Saving frame 668 of 1140...
# Saving frame 669 of 1140...
# Saving frame 670 of 1140...
# Saving frame 671 of 1140...
# Saving frame 672 of 1140...
# Saving frame 673 of 1140...
# Saving frame 674 of 1140...
# Saving frame 675 of 1140...
# Saving frame 676 of 1140...
# Saving frame 677 of 1140...
# Saving frame 678 of 1140...
# Saving frame 679 of 1140...
# Saving frame 680 of 1140...
# Saving frame 681 of 1140...
# Saving frame 682 of 1140...
# Saving frame 683 of 1140...
# Saving frame 684 of 1140...
# Saving frame 685 of 1140...
# Saving frame 686 of 1140...
# Saving frame 687 of 1140...
# Saving frame 688 of 1140...
# Saving frame 689 of 1140...
# Saving frame 690 of 1140...
# Saving frame 691 of 1140...
# Saving frame 692 of 1140...
# Saving frame 693 of 1140...
# Saving frame 694 of 1140...
# Saving frame 695 of 1140...
# Saving frame 696 of 1140...
# Saving frame 697 of 1140...
# Saving frame 698 of 1140...
# Saving frame 699 of 1140...
# Saving frame 700 of 1140...
# Saving frame 701 of 1140...
# Saving frame 702 of 1140...
# Saving frame 703 of 1140...
# Saving frame 704 of 1140...
# Saving frame 705 of 1140...
# Saving frame 706 of 1140...
# Saving frame 707 of 1140...
# Saving frame 708 of 1140...
# Saving frame 709 of 1140...
# Saving frame 710 of 1140...
# Saving frame 711 of 1140...
# Saving frame 712 of 1140...
# Saving frame 713 of 1140...
# Saving frame 714 of 1140...
# Saving frame 715 of 1140...
# Saving frame 716 of 1140...
# Saving frame 717 of 1140...
# Saving frame 718 of 1140...
# Saving frame 719 of 1140...
# Saving frame 720 of 1140...
# Saving frame 721 of 1140...
# Saving frame 722 of 1140...
# Saving frame 723 of 1140...
# Saving frame 724 of 1140...
# Saving frame 725 of 1140...
# Saving frame 726 of 1140...
# Saving frame 727 of 1140...
# Saving frame 728 of 1140...
# Saving frame 729 of 1140...
# Saving frame 730 of 1140...
# Saving frame 731 of 1140...
# Saving frame 732 of 1140...
# Saving frame 733 of 1140...
# Saving frame 734 of 1140...
# Saving frame 735 of 1140...
# Saving frame 736 of 1140...
# Saving frame 737 of 1140...
# Saving frame 738 of 1140...
# Saving frame 739 of 1140...
# Saving frame 740 of 1140...
# Saving frame 741 of 1140...
# Saving frame 742 of 1140...
# Saving frame 743 of 1140...
# Saving frame 744 of 1140...
# Saving frame 745 of 1140...
# Saving frame 746 of 1140...
# Saving frame 747 of 1140...
# Saving frame 748 of 1140...
# Saving frame 749 of 1140...
# Saving frame 750 of 1140...
# Saving frame 751 of 1140...
# Saving frame 752 of 1140...
# Saving frame 753 of 1140...
# Saving frame 754 of 1140...
# Saving frame 755 of 1140...
# Saving frame 756 of 1140...
# Saving frame 757 of 1140...
# Saving frame 758 of 1140...
# Saving frame 759 of 1140...
# Saving frame 760 of 1140...
# Saving frame 761 of 1140...
# Saving frame 762 of 1140...
# Saving frame 763 of 1140...
# Saving frame 764 of 1140...
# Saving frame 765 of 1140...
# Saving frame 766 of 1140...
# Saving frame 767 of 1140...
# Saving frame 768 of 1140...
# Saving frame 769 of 1140...
# Saving frame 770 of 1140...
# Saving frame 771 of 1140...
# Saving frame 772 of 1140...
# Saving frame 773 of 1140...
# Saving frame 774 of 1140...
# Saving frame 775 of 1140...
# Saving frame 776 of 1140...
# Saving frame 777 of 1140...
# Saving frame 778 of 1140...
# Saving frame 779 of 1140...
# Saving frame 780 of 1140...
# Saving frame 781 of 1140...
# Saving frame 782 of 1140...
# Saving frame 783 of 1140...
# Saving frame 784 of 1140...
# Saving frame 785 of 1140...
# Saving frame 786 of 1140...
# Saving frame 787 of 1140...
# Saving frame 788 of 1140...
# Saving frame 789 of 1140...
# Saving frame 790 of 1140...
# Saving frame 791 of 1140...
# Saving frame 792 of 1140...
# Saving frame 793 of 1140...
# Saving frame 794 of 1140...
# Saving frame 795 of 1140...
# Saving frame 796 of 1140...
# Saving frame 797 of 1140...
# Saving frame 798 of 1140...
# Saving frame 799 of 1140...
# Saving frame 800 of 1140...
# Saving frame 801 of 1140...
# Saving frame 802 of 1140...
# Saving frame 803 of 1140...
# Saving frame 804 of 1140...
# Saving frame 805 of 1140...
# Saving frame 806 of 1140...
# Saving frame 807 of 1140...
# Saving frame 808 of 1140...
# Saving frame 809 of 1140...
# Saving frame 810 of 1140...
# Saving frame 811 of 1140...
# Saving frame 812 of 1140...
# Saving frame 813 of 1140...
# Saving frame 814 of 1140...
# Saving frame 815 of 1140...
# Saving frame 816 of 1140...
# Saving frame 817 of 1140...
# Saving frame 818 of 1140...
# Saving frame 819 of 1140...
# Saving frame 820 of 1140...
# Saving frame 821 of 1140...
# Saving frame 822 of 1140...
# Saving frame 823 of 1140...
# Saving frame 824 of 1140...
# Saving frame 825 of 1140...
# Saving frame 826 of 1140...
# Saving frame 827 of 1140...
# Saving frame 828 of 1140...
# Saving frame 829 of 1140...
# Saving frame 830 of 1140...
# Saving frame 831 of 1140...
# Saving frame 832 of 1140...
# Saving frame 833 of 1140...
# Saving frame 834 of 1140...
# Saving frame 835 of 1140...
# Saving frame 836 of 1140...
# Saving frame 837 of 1140...
# Saving frame 838 of 1140...
# Saving frame 839 of 1140...
# Saving frame 840 of 1140...
# Saving frame 841 of 1140...
# Saving frame 842 of 1140...
# Saving frame 843 of 1140...
# Saving frame 844 of 1140...
# Saving frame 845 of 1140...
# Saving frame 846 of 1140...
# Saving frame 847 of 1140...
# Saving frame 848 of 1140...
# Saving frame 849 of 1140...
# Saving frame 850 of 1140...
# Saving frame 851 of 1140...
# Saving frame 852 of 1140...
# Saving frame 853 of 1140...
# Saving frame 854 of 1140...
# Saving frame 855 of 1140...
# Saving frame 856 of 1140...
# Saving frame 857 of 1140...
# Saving frame 858 of 1140...
# Saving frame 859 of 1140...
# Saving frame 860 of 1140...
# Saving frame 861 of 1140...
# Saving frame 862 of 1140...
# Saving frame 863 of 1140...
# Saving frame 864 of 1140...
# Saving frame 865 of 1140...
# Saving frame 866 of 1140...
# Saving frame 867 of 1140...
# Saving frame 868 of 1140...
# Saving frame 869 of 1140...
# Saving frame 870 of 1140...
# Saving frame 871 of 1140...
# Saving frame 872 of 1140...
# Saving frame 873 of 1140...
# Saving frame 874 of 1140...
# Saving frame 875 of 1140...
# Saving frame 876 of 1140...
# Saving frame 877 of 1140...
# Saving frame 878 of 1140...
# Saving frame 879 of 1140...
# Saving frame 880 of 1140...
# Saving frame 881 of 1140...
# Saving frame 882 of 1140...
# Saving frame 883 of 1140...
# Saving frame 884 of 1140...
# Saving frame 885 of 1140...
# Saving frame 886 of 1140...
# Saving frame 887 of 1140...
# Saving frame 888 of 1140...
# Saving frame 889 of 1140...
# Saving frame 890 of 1140...
# Saving frame 891 of 1140...
# Saving frame 892 of 1140...
# Saving frame 893 of 1140...
# Saving frame 894 of 1140...
# Saving frame 895 of 1140...
# Saving frame 896 of 1140...
# Saving frame 897 of 1140...
# Saving frame 898 of 1140...
# Saving frame 899 of 1140...
# Saving frame 900 of 1140...
# Saving frame 901 of 1140...
# Saving frame 902 of 1140...
# Saving frame 903 of 1140...
# Saving frame 904 of 1140...
# Saving frame 905 of 1140...
# Saving frame 906 of 1140...
# Saving frame 907 of 1140...
# Saving frame 908 of 1140...
# Saving frame 909 of 1140...
# Saving frame 910 of 1140...
# Saving frame 911 of 1140...
# Saving frame 912 of 1140...
# Saving frame 913 of 1140...
# Saving frame 914 of 1140...
# Saving frame 915 of 1140...
# Saving frame 916 of 1140...
# Saving frame 917 of 1140...
# Saving frame 918 of 1140...
# Saving frame 919 of 1140...
# Saving frame 920 of 1140...
# Saving frame 921 of 1140...
# Saving frame 922 of 1140...
# Saving frame 923 of 1140...
# Saving frame 924 of 1140...
# Saving frame 925 of 1140...
# Saving frame 926 of 1140...
# Saving frame 927 of 1140...
# Saving frame 928 of 1140...
# Saving frame 929 of 1140...
# Saving frame 930 of 1140...
# Saving frame 931 of 1140...
# Saving frame 932 of 1140...
# Saving frame 933 of 1140...
# Saving frame 934 of 1140...
# Saving frame 935 of 1140...
# Saving frame 936 of 1140...
# Saving frame 937 of 1140...
# Saving frame 938 of 1140...
# Saving frame 939 of 1140...
# Saving frame 940 of 1140...
# Saving frame 941 of 1140...
# Saving frame 942 of 1140...
# Saving frame 943 of 1140...
# Saving frame 944 of 1140...
# Saving frame 945 of 1140...
# Saving frame 946 of 1140...
# Saving frame 947 of 1140...
# Saving frame 948 of 1140...
# Saving frame 949 of 1140...
# Saving frame 950 of 1140...
# Saving frame 951 of 1140...
# Saving frame 952 of 1140...
# Saving frame 953 of 1140...
# Saving frame 954 of 1140...
# Saving frame 955 of 1140...
# Saving frame 956 of 1140...
# Saving frame 957 of 1140...
# Saving frame 958 of 1140...
# Saving frame 959 of 1140...
# Saving frame 960 of 1140...
# Saving frame 961 of 1140...
# Saving frame 962 of 1140...
# Saving frame 963 of 1140...
# Saving frame 964 of 1140...
# Saving frame 965 of 1140...
# Saving frame 966 of 1140...
# Saving frame 967 of 1140...
# Saving frame 968 of 1140...
# Saving frame 969 of 1140...
# Saving frame 970 of 1140...
# Saving frame 971 of 1140...
# Saving frame 972 of 1140...
# Saving frame 973 of 1140...
# Saving frame 974 of 1140...
# Saving frame 975 of 1140...
# Saving frame 976 of 1140...
# Saving frame 977 of 1140...
# Saving frame 978 of 1140...
# Saving frame 979 of 1140...
# Saving frame 980 of 1140...
# Saving frame 981 of 1140...
# Saving frame 982 of 1140...
# Saving frame 983 of 1140...
# Saving frame 984 of 1140...
# Saving frame 985 of 1140...
# Saving frame 986 of 1140...
# Saving frame 987 of 1140...
# Saving frame 988 of 1140...
# Saving frame 989 of 1140...
# Saving frame 990 of 1140...
# Saving frame 991 of 1140...
# Saving frame 992 of 1140...
# Saving frame 993 of 1140...
# Saving frame 994 of 1140...
# Saving frame 995 of 1140...
# Saving frame 996 of 1140...
# Saving frame 997 of 1140...
# Saving frame 998 of 1140...
# Saving frame 999 of 1140...
# Saving frame 1000 of 1140...
# Saving frame 1001 of 1140...
# Saving frame 1002 of 1140...
# Saving frame 1003 of 1140...
# Saving frame 1004 of 1140...
# Saving frame 1005 of 1140...
# Saving frame 1006 of 1140...
# Saving frame 1007 of 1140...
# Saving frame 1008 of 1140...
# Saving frame 1009 of 1140...
# Saving frame 1010 of 1140...
# Saving frame 1011 of 1140...
# Saving frame 1012 of 1140...
# Saving frame 1013 of 1140...
# Saving frame 1014 of 1140...
# Saving frame 1015 of 1140...
# Saving frame 1016 of 1140...
# Saving frame 1017 of 1140...
# Saving frame 1018 of 1140...
# Saving frame 1019 of 1140...
# Saving frame 1020 of 1140...
# Saving frame 1021 of 1140...
# Saving frame 1022 of 1140...
# Saving frame 1023 of 1140...
# Saving frame 1024 of 1140...
# Saving frame 1025 of 1140...
# Saving frame 1026 of 1140...
# Saving frame 1027 of 1140...
# Saving frame 1028 of 1140...
# Saving frame 1029 of 1140...
# Saving frame 1030 of 1140...
# Saving frame 1031 of 1140...
# Saving frame 1032 of 1140...
# Saving frame 1033 of 1140...
# Saving frame 1034 of 1140...
# Saving frame 1035 of 1140...
# Saving frame 1036 of 1140...
# Saving frame 1037 of 1140...
# Saving frame 1038 of 1140...
# Saving frame 1039 of 1140...
# Saving frame 1040 of 1140...
# Saving frame 1041 of 1140...
# Saving frame 1042 of 1140...
# Saving frame 1043 of 1140...
# Saving frame 1044 of 1140...
# Saving frame 1045 of 1140...
# Saving frame 1046 of 1140...
# Saving frame 1047 of 1140...
# Saving frame 1048 of 1140...
# Saving frame 1049 of 1140...
# Saving frame 1050 of 1140...
# Saving frame 1051 of 1140...
# Saving frame 1052 of 1140...
# Saving frame 1053 of 1140...
# Saving frame 1054 of 1140...
# Saving frame 1055 of 1140...
# Saving frame 1056 of 1140...
# Saving frame 1057 of 1140...
# Saving frame 1058 of 1140...
# Saving frame 1059 of 1140...
# Saving frame 1060 of 1140...
# Saving frame 1061 of 1140...
# Saving frame 1062 of 1140...
# Saving frame 1063 of 1140...
# Saving frame 1064 of 1140...
# Saving frame 1065 of 1140...
# Saving frame 1066 of 1140...
# Saving frame 1067 of 1140...
# Saving frame 1068 of 1140...
# Saving frame 1069 of 1140...
# Saving frame 1070 of 1140...
# Saving frame 1071 of 1140...
# Saving frame 1072 of 1140...
# Saving frame 1073 of 1140...
# Saving frame 1074 of 1140...
# Saving frame 1075 of 1140...
# Saving frame 1076 of 1140...
# Saving frame 1077 of 1140...
# Saving frame 1078 of 1140...
# Saving frame 1079 of 1140...
# Saving frame 1080 of 1140...
# Saving frame 1081 of 1140...
# Saving frame 1082 of 1140...
# Saving frame 1083 of 1140...
# Saving frame 1084 of 1140...
# Saving frame 1085 of 1140...
# Saving frame 1086 of 1140...
# Saving frame 1087 of 1140...
# Saving frame 1088 of 1140...
# Saving frame 1089 of 1140...
# Saving frame 1090 of 1140...
# Saving frame 1091 of 1140...
# Saving frame 1092 of 1140...
# Saving frame 1093 of 1140...
# Saving frame 1094 of 1140...
# Saving frame 1095 of 1140...
# Saving frame 1096 of 1140...
# Saving frame 1097 of 1140...
# Saving frame 1098 of 1140...
# Saving frame 1099 of 1140...
# Saving frame 1100 of 1140...
# Saving frame 1101 of 1140...
# Saving frame 1102 of 1140...
# Saving frame 1103 of 1140...
# Saving frame 1104 of 1140...
# Saving frame 1105 of 1140...
# Saving frame 1106 of 1140...
# Saving frame 1107 of 1140...
# Saving frame 1108 of 1140...
# Saving frame 1109 of 1140...
# Saving frame 1110 of 1140...
# Saving frame 1111 of 1140...
# Saving frame 1112 of 1140...
# Saving frame 1113 of 1140...
# Saving frame 1114 of 1140...
# Saving frame 1115 of 1140...
# Saving frame 1116 of 1140...
# Saving frame 1117 of 1140...
# Saving frame 1118 of 1140...
# Saving frame 1119 of 1140...
# Saving frame 1120 of 1140...
# Saving frame 1121 of 1140...
# Saving frame 1122 of 1140...
# Saving frame 1123 of 1140...
# Saving frame 1124 of 1140...
# Saving frame 1125 of 1140...
# Saving frame 1126 of 1140...
# Saving frame 1127 of 1140...
# Saving frame 1128 of 1140...
# Saving frame 1129 of 1140...
# Saving frame 1130 of 1140...
# Saving frame 1131 of 1140...
# Saving frame 1132 of 1140...
# Saving frame 1133 of 1140...
# Saving frame 1134 of 1140...
# Saving frame 1135 of 1140...
# Saving frame 1136 of 1140...
# Saving frame 1137 of 1140...
# Saving frame 1138 of 1140...
# Saving frame 1139 of 1140...
